# %% [markdown]
# # Scipy library is used for Scientific Calculations in Python

# %%
import scipy.stats as s

# %%
p_x_equals_k = s.binom.pmf(5,10,0.67)

# %%
p_x_equals_k
# Out:
# 0.1331509451872624

# %%
p_x_less_equals_k = s.binom.cdf(5,10,0.67)

# %%
p_x_less_equals_k
# Out:
# 0.20635140192297632

# %%
binomial_mean = s.binom.mean(10,0.67)

# %%
binomial_mean
# Out:
# 6.7

# %%
binomial_std = s.binom.std(10,0.67)

# %%
binomial_std
# Out:
# 1.4869431730903504

# %%
log_p_x_equals_2 = s.norm.logpdf(2,15,6)

# %%
log_p_x_equals_2
# Out:
# -5.05792022465495

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame(data={'radius_mean':np.random.normal(loc=65,scale=5,size=(569,))})

# %%
df['radius_mean']
# Out:
# 0      67.500378
# 1      68.434493
# 2      80.977352
# 3      58.229864
# 4      76.442429
# 5      63.925555
# 6      63.881777
# 7      66.057141
# 8      66.348936
# 9      68.767228
# 10     66.856997
# 11     62.128082
# 12     59.854614
# 13     66.226017
# 14     64.060418
# 15     67.917536
# 16     64.908640
# 17     66.390909
# 18     68.005452
# 19     69.007455
# 20     63.037831
# 21     59.214506
# 22     59.219364
# 23     59.934214
# 24     70.258398
# 25     65.896947
# 26     67.820805
# 27     71.731135
# 28     67.913936
# 29     59.507333
#          ...
# 539    63.806128
# 540    69.660290
# 541    66.730578
# 542    58.412469
# 543    57.315532
# 544    65.310613
# 545    69.000830
# 546    64.855973
# 547    76.462512
# 548    68.663102
# 549    64.233875
# 550    67.441565
# 551    67.187797
# 552    69.083254
# 553    62.859056
# 554    68.321861
# 555    68.057430
# 556    67.535338
# 557    61.515878
# 558    70.082501
# 559    60.892264
# ...

# %%
log_p_x_equals_k = s.norm.logpdf(df['radius_mean'],15,6)

# %%
np.sum(log_p_x_equals_k)
# Out:
# -21465.077076557794

# %%
log_p_x_equals_k = s.rayleigh.logpdf(df['radius_mean'],6.5)

# %%
log_p_x_equals_k
# Out:
# array([-1856.4121569 , -1913.81461898, -2769.12746842, -1334.04337851,
#        -2441.72399961, -1644.79669475, -1642.28443556, -1769.4396034 ,
#        -1786.85576243, -1934.47237913, -1817.38326432, -1543.22306695,
#        -1419.38046364, -1779.50876011, -1652.54803462, -1881.9391629 ,
#        -1701.71717345, -1789.36798555, -1887.3411643 , -1949.45567883,
#        -1594.22827631, -1385.44469783, -1385.70067367, -1423.62915395,
#        -2028.41157824, -1759.91441483, -1876.00442889, -2123.37255302,
#        -1881.71810754, -1400.91826001, -1917.24764563, -2160.59257698,
#        -1996.46967924, -1595.20007048, -2015.25614002, -1949.48891032,
#        -1533.11769906, -1490.09817873, -1148.22455212, -1830.29450219,
#        -1860.29879957, -1427.21390219, -1518.54183452, -1520.26803671,
#        -2278.10800041, -2090.31578613, -1793.4182928 , -1873.81508195,
#        -2052.21437266, -1852.44189887, -1777.68800536, -1990.28442533,
# ...

# %%
np.sum(log_p_x_equals_k)
# Out:
# -977210.0981827006
